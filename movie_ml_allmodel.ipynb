# %%
import pandas as pd
import numpy as np
import os
import ast
from sklearn.model_selection import train_test_split

# %%
os.chdir('C:\\Users\\mishr\\Downloads')
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
import numpy as np
import pandas as pd
import os
os.chdir('C:\\Users\\mishr\\Downloads')
credits = pd.read_csv('credits.csv')
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
# Merge datasets
movies_df = movies_df.merge(credits_df, left_on='id', right_on='movie_id', how='left')

# %% [markdown]
# ##### Merge Data Sets

# %%
movies = movies.merge(credits,left_on = 'id',right_on = 'movie_id',how='left')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline  title_x vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.   Avatar          7.2      11800    19995
#
# ...

# %%
# Keep only useful columns
movies_df = movies_df[['budget', 'genres', 'popularity', 'runtime', 'vote_average', 'vote_count', 'revenue', 'cast', 'crew']]
movies_df.dropna(inplace=True)

# %% [markdown]
# ##### Keeps only usefull columns

# %%
movies = movies[['budget','genres','popularity','runtime','vote_average','vote_count','revenue','cast','crew']]
movies.head(2)
# Out:
#       budget                                             genres  popularity  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  150.437577
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...  139.082615
#
#    runtime  vote_average  vote_count     revenue  \
# 0    162.0           7.2       11800  2787965087
# 1    169.0           6.9        4500   961000000
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %% [markdown]
# ##### Handle missing values

# %%
movies.isnull().sum()
# Out:
# budget          0
# genres          0
# popularity      0
# runtime         2
# vote_average    0
# vote_count      0
# revenue         0
# cast            0
# crew            0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# budget          0
# genres          0
# popularity      0
# runtime         0
# vote_average    0
# vote_count      0
# revenue         0
# cast            0
# crew            0
# dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4801 entries, 0 to 4802
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   budget        4801 non-null   int64
#  1   genres        4801 non-null   object
#  2   popularity    4801 non-null   float64
#  3   runtime       4801 non-null   float64
#  4   vote_average  4801 non-null   float64
#  5   vote_count    4801 non-null   int64
#  6   revenue       4801 non-null   int64
#  7   cast          4801 non-null   object
#  8   crew          4801 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 375.1+ KB

# %% [markdown]
# ##### Function to extract number of genres:-

# %%
def get_genre_count(obj):
    return len(ast.literal_eval(obj))

# %% [markdown]
# ##### Apply the function:-

# %%
movies['genre_count'] = movies['genres'].apply(get_genre_count)
movies['genre_count']
# Out:
# 0       4
# 1       3
# 2       3
# 3       4
# 4       3
#        ..
# 4798    3
# 4799    2
# 4800    4
# 4801    0
# 4802    1
# Name: genre_count, Length: 4801, dtype: int64

# %%
def get_cast_count(obj):
    return len(ast.literal_eval(obj))

def get_crew_count(obj):
    return len(ast.literal_eval(obj))

# %% [markdown]
# ##### Function to extract number of cast:-

# %%
def get_cast_count(obj):
    cast = ast.literal_eval(obj)
    return len(cast)

# %% [markdown]
# ##### Apply the function:-

# %%
movies['cast_count'] = movies['cast'].apply(get_cast_count)
movies['cast_count']
# Out:
# 0        83
# 1        34
# 2        83
# 3       158
# 4        27
#        ...
# 4798      7
# 4799      5
# 4800      7
# 4801      5
# 4802      8
# Name: cast_count, Length: 4801, dtype: int64

# %% [markdown]
# ##### Function to extract number of crew:-

# %%
def get_crew_count(obj):
    crew = ast.literal_eval(obj)
    return len(crew)

# %% [markdown]
# ##### Apply the function:-

# %%
movies['crew_count']=movies['crew'].apply(get_crew_count)
movies['crew_count']
# Out:
# 0       153
# 1        32
# 2       155
# 3       217
# 4       132
#        ...
# 4798     11
# 4799      8
# 4800     13
# 4801      2
# 4802      5
# Name: crew_count, Length: 4801, dtype: int64

# %%
# Drop original text columns
movies_df.drop(['genres', 'cast', 'crew'], axis=1, inplace=True)

# %% [markdown]
# ##### Drops original text columns:-

# %%
movies.drop(['genres','cast','crew'],axis=1,inplace=True)

# %%
movies.head(2)
# Out:
#       budget  popularity  runtime  vote_average  vote_count     revenue  \
# 0  237000000  150.437577    162.0           7.2       11800  2787965087
# 1  300000000  139.082615    169.0           6.9        4500   961000000
#
#    genre_count  cast_count  crew_count
# 0            4          83         153
# 1            3          34          32

# %% [markdown]
# ##### Split features and target:-

# %%
x = movies.drop('revenue',axis=1)
y = movies['revenue']

# %% [markdown]
# ##### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ### ✅  Model 1 — Linear Regression

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ##### Create Model:-

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %% [markdown]
# #### Train Model:-

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##### Predict:-

# %%
y_pred = lr_model.predict(X_test)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 1.18761384e+08, -1.39012993e+07,  5.60128384e+06,  6.88494667e+07,
#         7.96693952e+08,  1.71583028e+08,  3.96065092e+06,  1.87193920e+08,
#        -1.55403664e+07,  1.09033831e+08,  5.48229003e+06, -1.74362201e+07,
#        -1.49869268e+07,  8.37673081e+07,  2.78341021e+08,  1.56590187e+08,
#        -7.89335972e+06,  2.33657810e+08,  3.43516537e+07, -4.60014087e+06,
#         7.66237257e+07,  1.10349961e+08,  1.31481200e+07,  2.10227415e+08,
#         8.94792795e+07,  1.12045661e+07,  1.09001254e+05,  7.72228745e+07,
#         9.14378744e+05,  1.69696671e+08, -7.40847783e+06, -1.89227996e+07,
#         3.79063240e+08,  1.82155781e+07,  2.27105867e+06,  2.07948531e+07,
#         3.80296445e+08,  2.16731466e+08,  7.71745210e+07,  9.39332390e+05,
#         5.68243022e+08,  3.12051359e+08, -1.64088885e+07,  8.25406811e+08,
#        -1.63988918e+07,  2.53215034e+08,  6.73947249e+06,  5.74080041e+06,
# ...

# %% [markdown]
# ##### Evaluate:-

# %%
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

# %%
print(" Linear Regression Results")
print("Mean Squared Error:",mse)
print("R² Score:",r2)
# Out:
#  Linear Regression Results
# Mean Squared Error: 6268489178125543.0
# R² Score: 0.7611572812311432

# %% [markdown]
# #####  Model 2 — Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor(random_state=42)
model
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ##### Train:-

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Predict
y_pred = dt_model.predict(X_test)

# %% [markdown]
# ##### Predict:-

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1.72180800e+07, 0.00000000e+00, 0.00000000e+00, 4.85720000e+07,
#        7.47862775e+08, 8.91621620e+07, 2.35075670e+07, 2.04999686e+08,
#        0.00000000e+00, 6.56647210e+07, 8.90000000e+06, 0.00000000e+00,
#        0.00000000e+00, 1.17760134e+08, 5.16642939e+08, 1.36442920e+07,
#        3.41531010e+07, 3.94076160e+07, 4.85314700e+07, 0.00000000e+00,
#        3.33726060e+07, 1.16672912e+08, 1.04433160e+07, 4.70654000e+08,
#        4.71262950e+07, 4.55545330e+07, 1.40565280e+07, 0.00000000e+00,
#        6.85245000e+06, 1.12265139e+08, 5.00000000e+05, 0.00000000e+00,
#        3.27311859e+08, 0.00000000e+00, 5.73110300e+06, 1.61238510e+07,
#        2.64218220e+08, 1.44492830e+08, 1.63743280e+07, 6.77380900e+07,
#        8.75958308e+08, 1.73930596e+08, 0.00000000e+00, 8.80674609e+08,
#        0.00000000e+00, 1.62949164e+08, 2.28890180e+07, 0.00000000e+00,
#        2.30685453e+08, 1.14908830e+08, 1.98394920e+07, 4.00779200e+06,
# ...

# %% [markdown]
# ##### Evaluate

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("🔹 Decision Tree Results")
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# 🔹 Decision Tree Results
# Mean Squared Error: 1.9707587107789024e+16
# R² Score: 0.2490991766207481

# %% [markdown]
# ##### ✅  Model 3 — Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("🔹 Random Forest Results")
print("Mean Squared Error:", mse)
print("R² Score:", r2)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100,random_state=42)
rf_model
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ##### Model train

# %%
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_model.predict(x_test)
y_pred
# Out:
# array([5.96210230e+07, 5.68846680e+05, 1.84591862e+07, 6.17493297e+07,
#        1.03769391e+09, 1.79438341e+08, 1.38256924e+07, 1.91563513e+08,
#        5.28972000e+03, 9.67964096e+07, 1.05603250e+07, 2.82156000e+03,
#        5.41668380e+05, 1.17897115e+08, 2.91650516e+08, 1.21626382e+08,
#        2.07338572e+06, 1.80600353e+08, 6.81314904e+07, 3.20623335e+06,
#        7.54652076e+07, 8.77001545e+07, 8.19026120e+06, 2.10683334e+08,
#        1.00067498e+08, 3.77103728e+07, 4.51045593e+06, 2.34143796e+07,
#        4.76701011e+06, 1.11989340e+08, 2.82827470e+06, 2.28554480e+05,
#        3.59958366e+08, 1.15605484e+07, 5.94650741e+06, 1.49687453e+07,
#        2.79872620e+08, 1.62089751e+08, 5.35400174e+07, 5.58086722e+06,
#        6.00147905e+08, 2.26794651e+08, 1.04708917e+06, 8.36067379e+08,
#        1.48895784e+06, 2.55839083e+08, 2.79361759e+07, 5.70037034e+06,
#        2.64406239e+08, 7.50499562e+07, 6.13238195e+07, 2.58576675e+07,
# ...

# %% [markdown]
# ##### Evaluate:

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("🔹 Random Forest Results")
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# 🔹 Random Forest Results
# Mean Squared Error: 6819514986525128.0
# R² Score: 0.740162030469728

# %% [markdown]
# ##### ✅  Model 4 — Support Vector Regressor (SVR)

# %%
from sklearn.svm import SVR

# %% [markdown]
# ##### Create model

# %%
svr_model = SVR()

# %%
svr_model.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred = svr_model.predict(x_test)
y_pred
# Out:
# array([18754154.77413114, 18752873.10530135, 18753023.20196117,
#        18753039.61204208, 18753637.93644592, 18754154.77413163,
#        18752933.10986521, 18754053.16724981, 18752867.10838375,
#        18753890.91023892, 18752928.43963222, 18752867.10838375,
#        18752867.10838377, 18753207.16160461, 18753930.80818503,
#        18754037.42171277, 18752867.1083838 , 18753947.55352474,
#        18753133.46981053, 18752909.22581988, 18753528.59913984,
#        18754156.34365921, 18753133.46981027, 18752975.35257259,
#        18753392.51605967, 18753076.48503011, 18752867.10953   ,
#        18754105.21019151, 18752949.30348044, 18754076.30739869,
#        18752890.4354751 , 18752867.10838375, 18753528.59914472,
#        18752868.1749671 , 18753003.42195809, 18753258.63289255,
#        18753722.33311958, 18754154.7741317 , 18753528.59914001,
#        18752867.10838389, 18753673.07460216, 18753981.60144341,
#        18752867.10838376, 18753687.20019158, 18752875.93652789,
# ...

# %% [markdown]
# ##### Evaluate

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("🔹 Support Vector Regressor Results")
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# 🔹 Support Vector Regressor Results
# Mean Squared Error: 3.109114065045056e+16
# R² Score: -0.18463833175174837

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##### List of model names and their scores

# %%
model_names = ['Linear Regression','Decision Tree','Random Forest','SVR']
mse_scores = []
r2_scores = []

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# %%
models = [
    LinearRegression(),
    DecisionTreeRegressor(random_state=42),
    RandomForestRegressor(n_estimators=100, random_state=42),
    #GradientBoostingRegressor(n_estimators=100, random_state=42),
    SVR()]

# %%
for model in models:
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    mse_scores.append(mean_squared_error(y_test, y_pred))
    r2_scores.append(r2_score(y_test, y_pred))

# %%
models = [
    ('Linear Regression', LinearRegression()),
    ('Decision Tree', DecisionTreeRegressor(random_state=42)),
    ('Random Forest', RandomForestRegressor(n_estimators=100, random_state=42)),
    #('Gradient Boosting', GradientBoostingRegressor(n_estimators=100, random_state=42)),
    ('Support Vector Regressor', SVR())
]

results = []

# Train and evaluate each model
for name, model in models:
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    results.append({
        'Model': name,
        'MSE': round(mse, 2),
        'R² Score': round(r2, 4)
    })

# Create a table
results_df = pd.DataFrame(results)

# Display table
print(results_df)
# Out:
#                       Model           MSE  R² Score
# 0         Linear Regression  6.268489e+15    0.7612
# 1             Decision Tree  1.970759e+16    0.2491
# 2             Random Forest  6.819515e+15    0.7402
# 3  Support Vector Regressor  3.109114e+16   -0.1846

# %% [markdown]
# ##### Plot MSE:-

# %%
# Plot MSE
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.bar(model_names, mse_scores, color='skyblue')
plt.title('Mean Squared Error (MSE)')
plt.ylabel('MSE')
plt.xticks(rotation=15)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Linear Regression'),
#   Text(1, 0, 'Decision Tree'),
#   Text(2, 0, 'Random Forest'),
#   Text(3, 0, 'SVR')])

# %% [markdown]
# ##### Plot R2 Score:-

# %%
# Plot R2 Score
plt.subplot(1, 2, 2)
plt.bar(model_names, r2_scores, color='lightgreen')
plt.title('R² Score')
plt.ylabel('R²')
plt.xticks(rotation=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### ✅ Final Report: Model Evaluation and Selection

# %% [markdown]
# ##### In this project, we built a machine learning model to predict movie revenue using various features such as budget, popularity, runtime, vote average, vote count, and counts of genres, cast, and crew.
# ##### We trained and evaluated five regression models: Linear Regression, Decision Tree Regressor, Random Forest Regressor and Support Vector Regressor.
# ##### All models were tested on the same dataset using Mean Squared Error (MSE) and R² score as evaluation metrics.
# ##### Based on the results, the Random Forest Regressor performed the best, achieving the lowest MSE and highest R² score, indicating better prediction accuracy and generalization.
# ##### Therefore, the Random Forest model was selected as the final model for revenue prediction.
# ##### Its ability to handle non-linear relationships and reduce overfitting using ensemble learning made it the most suitable choice for our dataset.

# %% [markdown]
# ##### Save model

# %%
import pickle


with open('best_model.pkl', 'wb') as f:
    pickle.dump(rf_model, f)
